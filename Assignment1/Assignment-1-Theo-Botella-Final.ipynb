# %% [markdown]
# # CS171 - Winter 2020 - Assignment 1
# ### Instructor: Vagelis Papalexakis
# ### TA: Yorgos Tsitsikas
#
# In this first assignment you will explore a dataset, visualizing the dataset in various ways, and doing a preliminary analysis on the data.
#
# For this assignment we are going to use the functionality of Pandas (the library, *not* the unbearably cute animal): https://pandas.pydata.org/ in order to manipulate datasets.
# In addition to Pandas, we are going to use Matplotlib (https://matplotlib.org/) and Numpy (http://www.numpy.org/) and you may also find Seaborn (https://seaborn.pydata.org/) useful for some data visualization.
#
# Unless you are explicitly asked to *implement* a particular functionality, you may assume that you may use an existing implementation from the libraries above (or some other library that you may find, as long as you *document* it).
#
# Before you start, make sure you have installed all those packages in your local Jupyter instance, as follows:
#
# conda install numpy pandas matplotlib seaborn
#
# ## Academic Integrity
# Each assignment should be done  individually. You may discuss general approaches with other students in the class, and ask questions to the TAs, but  you must only submit work that is yours . If you receive help by any external sources (other than the TA and the instructor), you must properly credit those sources, and if the help is significant, the appropriate grade reduction will be applied. If you fail to do so, the instructor and the TAs are obligated to take the appropriate actions outlined at http://conduct.ucr.edu/policies/academicintegrity.html . Please read carefully the UCR academic integrity policies included in the link.

# %%
#!pip install seaborn
import pandas as pd, matplotlib.pyplot as plt, seaborn as sb, numpy as np
#make sure you import here everything else you may need

# %% [markdown]
# ## Question 0: Getting real data [0%]
#
# In this assignment you are going to use data from the UCI Machine Learning repository ( https://archive.ics.uci.edu/ml/index.php ). In particular, you are going to use the famous Iris dataset: https://archive.ics.uci.edu/ml/datasets/Iris

# %%
data_names = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'label']
data = pd.read_csv('iris.data', 
                   names = data_names)
data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width        label
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %% [markdown]
# ## Question 1: Data Visualization [20%]

# %% [markdown]
# ### Question 1a: Scatterplots [10%]
# 1. Plot the scatterplot of all pairs of features and color the points by class label [5%]
# 2. Which pair of features is (visually) the most correlated?  [2.5%]
# 3. Can you think of a reason why looking at this plot would be useful in a task where we would have to classify flowers by label? [2.5%]

# %%
#1- 
#USING PANDAS (can't add colors)
scat_mat = pd.plotting.scatter_matrix(data, alpha=0.5)


#USING SEABORN (pairplot function)
sb.set()
data_sb = sb.load_dataset('iris')
sb.pairplot(data_sb, hue="species")

# %% [markdown]
# Your answer here:
# 2. petal_width and petal_lenght are the features that are visually the most correlated (linearly correlated).
# 3. Looking at the plot can help us spot the correlated features (as in question 1)  and give us an idea about what can be the important features to classify flowers by lable. We can see that smaller petal_lenght and smaller petal_width would/could leed to setosa flower. Without seeing an image of the flower we can imagine the setosa being the flower with small petals and a long sepal, virginica big petals smaller sepal.

# %% [markdown]
# ### Question 1b: Boxplot and Histogram [10%]
#
# 1. Plot the boxplot for each feature of the dataset (you can put all boxplots on a single figure) [4%]
# 2. Plot the histogram only for petal length [4%]
# 3. Does the histogram for petal length give more information than the boxplot? If so, what information? [2%]

# %%
#1- Plot the boxplot for each feature of the dataset
box_p_lenght = data['petal_length']
box_p_width = data['petal_width'] 
box_s_lenght = data['sepal_length']
box_s_width = data['sepal_width'] 

fig, axes = plt.subplots(2,2) #add figure of 4 (2x2) subplots to plot the boxplots

axes[0,0].boxplot(box_p_lenght)
axes[0,0].set_title('petal_length')

axes[0,1].boxplot(box_p_width)
axes[0,1].set_title('petal_width')

axes[1,0].boxplot(box_s_lenght)
axes[1,0].set_title('sepal_length')

axes[1,1].boxplot(box_p_width)
axes[1,1].set_title('sepal_width')
display()

# %%
#1- Plot all boxplots on a single figure
data_boxplot = [data['petal_length'], data['petal_width'], data['sepal_length'], data['sepal_width']] 

plt.subplots()
plt.boxplot(data_boxplot)

plt.xticks([1, 2, 3, 4], ['petal_length', 'petal_width', 'sepal_length', 'sepal_width'])
display()

# %%
#2- Plot the histogram only for petal length 
plt.hist(data['petal_length'])
display()
#data['petal_length']

# %% [markdown]
# Does the histogram for petal length give more information than the boxplot? If so, what information? [2%]
# Your answer here:
#
# 3. Yes the histogram for petal length is giving more information than the boxplot because it also shows the frequency distribution.

# %% [markdown]
# ## Question 2: Distance computation [40%]

# %% [markdown]
# ### Question 2a: Implement the Lp distance function [20%]
# 1. Write code that implements the Lp distance function between two data points as we saw it in class [15%]
# 2. Verify that it is correct by comparing it for p=2 against an existing implementation in Numpy for the two selected data points below. Note that the difference of the distances may not be exactly 0 due to numerical precision issues. [5%]

# %% [markdown]
# <img src="lp.png">

# %%
### 1-Write code that implements the Lp distance function between two data points as we saw it in class [15%]
### ELIF function
'''
def lp(p, X, Y):
    if p==1:
        dist = sum([abs((x - y)) ** p for x, y in zip(X, Y)])**1/p
        print("Manhattan distance 'L1' from x to y: ",dist)
    elif p==2:
        dist = sum([abs((x - y)) ** p for x, y in zip(X, Y)])**1/p
        print("Euclidean distance 'L2' from x to y: ",dist)
    else:
        print("Choose L1 or L2 by key in 1 or 2")
    return
'''
# Out:
# '\ndef lp(p, X, Y):\n    if p==1:\n        dist = sum([abs((x - y)) ** p for x, y in zip(X, Y)])**1/p\n        print("Manhattan distance \'L1\' from x to y: ",dist)\n    elif p==2:\n        dist = sum([abs((x - y)) ** p for x, y in zip(X, Y)])**1/p\n        print("Euclidean distance \'L2\' from x to y: ",dist)\n    else:\n        print("Choose L1 or L2 by key in 1 or 2")\n    return\n'

# %%
#1-Write code that implements the Lp distance function between two data points as we saw it in class [15%]
def lp(p, X, Y):
    dist = (sum([abs((x - y)) ** p for x, y in zip(X, Y)]))**(1/p)
    print("L"+str(p)+" Distance from x to y: ",dist)
    return dist

# %%
X = list(data.loc[3])[0:4]
Y = list(data.loc[5])[0:4]
lp(2, X, Y)
# Out:
# L2 Distance from x to y:  1.1661903789690604
# 1.1661903789690604

# %%
#Verify that it is correct by comparing it for p=2 against an existing implementation in Numpy for the two selected data points below.
import math
from numpy import linalg

def compare(X,Y):
    lp_ = lp(2,X,Y)
    lp_np = np.linalg.norm(np.subtract(X,Y))
            #diff = (np.diff([X, Y]) ** 2).sum()    WORKS ONLY WITH 2D points
            #lp_np = math.sqrt(diff)
    print("L2 with Numpy = " + str(lp_np) + "\nDifference of the distance : " + str(lp_ - lp_np))
    return
#Note that the difference of the distances may not be exactly 0 due to numerical precision issues.

# %%
compare(X, Y)
# Out:
# L2 Distance from x to y:  1.1661903789690604
# L2 with Numpy = 1.1661903789690604
# Difference of the distance : 0.0

# %% [markdown]
# ### Question 2b: Compute the distance matrix between all data points [20%]
# 1. Compute an $N\times N$ distance matrix between all data points (where $N$ is the number of data points) [5%]
# 2. Plot the above matrix and include a colorbar. [5%]
# 3. What is the minimum number of distance computations that you can do in order to populate every value of this matrix? (note: it is OK if in the first two questions you do all the $N^2$ computations) [5%]
# 4. Note that the data points in your dataset are sorted by class. What do you observe in the distance matrix? [5%]

# %%
#1. Compute an N*N distance matrix between all data points (where N is the number of data points) [5%]

#Initialize a 2D matrix with 0
n = len(data)
matrix = np.zeros((n,n))
matrix
#feed the matrix with a double for loop
for i in range(n):
    for j in range(n):
            d1 = list(data.loc[i])[0:4] #remove label at [5] (species) and cast into a list of the 5 elements
            d2 = list(data.loc[j])[0:4] 
            #print(d1,d2)
            d1f = [float(i) for i in d1]
            d2f = [float(i) for i in d2]
            matrix[i][j]=lp(2, d1f, d2f)
# Out:
# L2 Distance from x to y:  0.0
# L2 Distance from x to y:  0.5385164807134502
# L2 Distance from x to y:  0.509901951359278
# L2 Distance from x to y:  0.648074069840786
# L2 Distance from x to y:  0.1414213562373093
# L2 Distance from x to y:  0.6164414002968979
# L2 Distance from x to y:  0.5196152422706632
# L2 Distance from x to y:  0.17320508075688762
# L2 Distance from x to y:  0.9219544457292882
# L2 Distance from x to y:  0.4690415759823426
# L2 Distance from x to y:  0.37416573867739483
# L2 Distance from x to y:  0.3741657386773941
# L2 Distance from x to y:  0.5916079783099616
# L2 Distance from x to y:  0.9949874371066197
# L2 Distance from x to y:  0.8831760866327848
# L2 Distance from x to y:  1.1045361017187267
# L2 Distance from x to y:  0.5477225575051664
# L2 Distance from x to y:  0.09999999999999998
# L2 Distance from x to y:  0.7416198487095667
# L2 Distance from x to y:  0.33166247903553986
# L2 Distance from x to y:  0.4358898943540679
# L2 Distance from x to y:  0.30000000000000016
# L2 Distance from x to y:  0.648074069840786
# L2 Distance from x to y:  0.46904157598234303
# L2 Distance from x to y:  0.5916079783099616
# L2 Distance from x to y:  0.5477225575051662
# L2 Distance from x to y:  0.316227766016838
# L2 Distance from x to y:  0.14142135623730995
# L2 Distance from x to y:  0.14142135623730995
# L2 Distance from x to y:  0.53851648071345
# L2 Distance from x to y:  0.5385164807134504
# L2 Distance from x to y:  0.3872983346207423
# L2 Distance from x to y:  0.6244997998398396
# L2 Distance from x to y:  0.8062257748298554
# L2 Distance from x to y:  0.4690415759823426
# L2 Distance from x to y:  0.37416573867739383
# L2 Distance from x to y:  0.41231056256176635
# L2 Distance from x to y:  0.4690415759823426
# L2 Distance from x to y:  0.866025403784438
# L2 Distance from x to y:  0.14142135623730964
# L2 Distance from x to y:  0.17320508075688743
# L2 Distance from x to y:  1.3490737563232043
# L2 Distance from x to y:  0.7681145747868601
# L2 Distance from x to y:  0.45825756949558394
# L2 Distance from x to y:  0.6164414002968975
# L2 Distance from x to y:  0.5916079783099616
# L2 Distance from x to y:  0.3605551275463989
# L2 Distance from x to y:  0.58309518948453
# L2 Distance from x to y:  0.30000000000000027
# L2 Distance from x to y:  0.22360679774997896
# L2 Distance from x to y:  4.003748243833521
# L2 Distance from x to y:  3.6166282640050254
# L2 Distance from x to y:  4.164132562731403
# L2 Distance from x to y:  3.093541659651604
# L2 Distance from x to y:  3.792097045171708
# L2 Distance from x to y:  3.416138170507745
# L2 Distance from x to y:  3.7854986461495406
# L2 Distance from x to y:  2.345207879911715
# L2 Distance from x to y:  3.749666651850535
# L2 Distance from x to y:  2.8879058156387303
# L2 Distance from x to y:  2.703701166919155
# L2 Distance from x to y:  3.228002478313795
# L2 Distance from x to y:  3.146426544510455
# L2 Distance from x to y:  3.7
# L2 Distance from x to y:  2.5806975801127883
# L2 Distance from x to y:  3.627671429443412
# L2 Distance from x to y:  3.4351128074635335
# L2 Distance from x to y:  3.009983388658482
# L2 Distance from x to y:  3.7682887362833544
# L2 Distance from x to y:  2.882707061079915
# L2 Distance from x to y:  3.8535697735995385
# L2 Distance from x to y:  3.0757112998459397
# L2 Distance from x to y:  4.047221268969613
# L2 Distance from x to y:  3.6578682316343767
# L2 Distance from x to y:  3.416138170507745
# L2 Distance from x to y:  3.59722114972099
# L2 Distance from x to y:  4.047221268969612
# L2 Distance from x to y:  4.244997055358225
# L2 Distance from x to y:  3.531288716601915
# L2 Distance from x to y:  2.4939927826679855
# L2 Distance from x to y:  2.8178005607210745
# L2 Distance from x to y:  2.7018512172212596
# L2 Distance from x to y:  2.8948229652260253
# L2 Distance from x to y:  4.135214625627066
# L2 Distance from x to y:  3.411744421846396
# L2 Distance from x to y:  3.5199431813596087
# L2 Distance from x to y:  3.9115214431215897
# L2 Distance from x to y:  3.6180105030251095
# L2 Distance from x to y:  2.9999999999999996
# L2 Distance from x to y:  3.0215889859476257
# L2 Distance from x to y:  3.3120990323358397
# L2 Distance from x to y:  3.59583091927304
# L2 Distance from x to y:  3.0099833886584824
# L2 Distance from x to y:  2.387467277262665
# L2 Distance from x to y:  3.1527765540868895
# L2 Distance from x to y:  3.07408522978788
# L2 Distance from x to y:  3.1256999216175574
# L2 Distance from x to y:  3.3451457367355464
# L2 Distance from x to y:  2.0904544960366875
# L2 Distance from x to y:  3.057776970284131
# L2 Distance from x to y:  5.2848841046895245
# L2 Distance from x to y:  4.208325082500163
# L2 Distance from x to y:  5.301886456724625
# L2 Distance from x to y:  4.690415759823429
# L2 Distance from x to y:  5.056678751908213
# L2 Distance from x to y:  6.0950799830683104
# L2 Distance from x to y:  3.591656999213594
# L2 Distance from x to y:  5.636488268416782
# L2 Distance from x to y:  5.047771785649585
# L2 Distance from x to y:  5.639148871948673
# L2 Distance from x to y:  4.356604182158392
# L2 Distance from x to y:  4.519955751995809
# L2 Distance from x to y:  4.853864439804639
# L2 Distance from x to y:  4.190465367951393
# L2 Distance from x to y:  4.417012565071555
# L2 Distance from x to y:  4.626013402488151
# L2 Distance from x to y:  4.645427859734774
# L2 Distance from x to y:  6.240192304729079
# L2 Distance from x to y:  6.498461356351979
# L2 Distance from x to y:  4.141255848169732
# L2 Distance from x to y:  5.121523210920752
# L2 Distance from x to y:  4.028647415696738
# L2 Distance from x to y:  6.211280061307815
# L2 Distance from x to y:  4.109744517606904
# L2 Distance from x to y:  4.969909455915672
# L2 Distance from x to y:  5.31224999411737
# L2 Distance from x to y:  3.9774363602702683
# L2 Distance from x to y:  4.007492981902776
# L2 Distance from x to y:  4.840454524112379
# L2 Distance from x to y:  5.0970579749498635
# L2 Distance from x to y:  5.546169849544818
# L2 Distance from x to y:  6.014149981501959
# L2 Distance from x to y:  4.880573736764972
# L2 Distance from x to y:  4.160528812542944
# L2 Distance from x to y:  4.570557952810575
# L2 Distance from x to y:  5.788782255362521
# L2 Distance from x to y:  4.891829923454003
# L2 Distance from x to y:  4.606517122512408
# L2 Distance from x to y:  3.8961519477556315
# L2 Distance from x to y:  4.796873982084583
# L2 Distance from x to y:  5.0199601592044525
# L2 Distance from x to y:  4.636809247747852
# L2 Distance from x to y:  4.208325082500163
# L2 Distance from x to y:  5.2573757712379665
# L2 Distance from x to y:  5.136146415358503
# L2 Distance from x to y:  4.654030511288039
# L2 Distance from x to y:  4.27668095606862
# L2 Distance from x to y:  4.459820624195552
# L2 Distance from x to y:  4.650806381693394
# L2 Distance from x to y:  4.1400483088968905
# L2 Distance from x to y:  0.5385164807134502
# L2 Distance from x to y:  0.0
# L2 Distance from x to y:  0.30000000000000016
# L2 Distance from x to y:  0.3316624790355407
# L2 Distance from x to y:  0.608276253029822
# L2 Distance from x to y:  1.0908712114635715
# L2 Distance from x to y:  0.5099019513592788
# L2 Distance from x to y:  0.42426406871192834
# L2 Distance from x to y:  0.5099019513592785
# L2 Distance from x to y:  0.17320508075688784
# L2 Distance from x to y:  0.8660254037844388
# L2 Distance from x to y:  0.4582575694955841
# L2 Distance from x to y:  0.1414213562373099
# L2 Distance from x to y:  0.6782329983125273
# L2 Distance from x to y:  1.360147050873544
# L2 Distance from x to y:  1.6278820596099708
# L2 Distance from x to y:  1.0535653752852738
# L2 Distance from x to y:  0.5477225575051659
# L2 Distance from x to y:  1.1747340124470729
# L2 Distance from x to y:  0.8366600265340752
# L2 Distance from x to y:  0.7071067811865475
# L2 Distance from x to y:  0.7615773105863909
# L2 Distance from x to y:  0.7810249675906658
# L2 Distance from x to y:  0.5567764362830019
# L2 Distance from x to y:  0.6480740698407861
# L2 Distance from x to y:  0.22360679774997896
# L2 Distance from x to y:  0.49999999999999994
# L2 Distance from x to y:  0.5916079783099616
# L2 Distance from x to y:  0.49999999999999983
# L2 Distance from x to y:  0.3464101615137758
# L2 Distance from x to y:  0.24494897427831822
# L2 Distance from x to y:  0.6782329983125268
# L2 Distance from x to y:  1.1489125293076055
# L2 Distance from x to y:  1.3416407864998738
# L2 Distance from x to y:  0.17320508075688784
# L2 Distance from x to y:  0.3
# L2 Distance from x to y:  0.7874007874011809
# L2 Distance from x to y:  0.17320508075688784
# L2 Distance from x to y:  0.5099019513592784
# L2 Distance from x to y:  0.4582575694955836
# L2 Distance from x to y:  0.529150262212918
# L2 Distance from x to y:  0.8185352771872454
# L2 Distance from x to y:  0.5477225575051662
# L2 Distance from x to y:  0.6782329983125268
# L2 Distance from x to y:  0.9848857801796101
# L2 Distance from x to y:  0.14142135623730986
# L2 Distance from x to y:  0.8485281374238567
# L2 Distance from x to y:  0.3605551275463996
# L2 Distance from x to y:  0.812403840463596
# L2 Distance from x to y:  0.31622776601683766
# L2 Distance from x to y:  4.096339829652808
# L2 Distance from x to y:  3.6864617182333523
# L2 Distance from x to y:  4.236744032862973
# L2 Distance from x to y:  2.9698484809834995
# L2 Distance from x to y:  3.811823710509183
# L2 Distance from x to y:  3.3911649915626345
# L2 Distance from x to y:  3.8600518131237567
# L2 Distance from x to y:  2.1470910553583886
# L2 Distance from x to y:  3.788139384975162
# L2 Distance from x to y:  2.8053520278211073
# L2 Distance from x to y:  2.4617067250182343
# L2 Distance from x to y:  3.2449961479175906
# L2 Distance from x to y:  3.0413812651491097
# L2 Distance from x to y:  3.712142238654117
# L2 Distance from x to y:  2.5592967784139455
# L2 Distance from x to y:  3.7000000000000006
# L2 Distance from x to y:  3.433656942677879
# L2 Distance from x to y:  2.971531591620725
# L2 Distance from x to y:  3.6918829883949464
# L2 Distance from x to y:  2.792848008753788
# L2 Distance from x to y:  3.893584466786357
# L2 Distance from x to y:  3.0740852297878796
# L2 Distance from x to y:  4.018706259482024
# L2 Distance from x to y:  3.6565010597564442
# L2 Distance from x to y:  3.4467375879228173
# L2 Distance from x to y:  3.651027252705737
# L2 Distance from x to y:  4.080441152620633
# L2 Distance from x to y:  4.295346318982906
# L2 Distance from x to y:  3.5383612025908264
# L2 Distance from x to y:  2.4186773244895647
# L2 Distance from x to y:  2.7
# L2 Distance from x to y:  2.5787593916455256
# L2 Distance from x to y:  2.8548204847240393
# L2 Distance from x to y:  4.11703777004778
# L2 Distance from x to y:  3.398529093593286
# L2 Distance from x to y:  3.59722114972099
# L2 Distance from x to y:  3.9786932528155523
# L2 Distance from x to y:  3.55808937493144
# L2 Distance from x to y:  2.9983328701129897
# L2 Distance from x to y:  2.929163703175362
# L2 Distance from x to y:  3.2434549480453714
# L2 Distance from x to y:  3.622154055254966
# L2 Distance from x to y:  2.9546573405388314
# L2 Distance from x to y:  2.179449471770337
# L2 Distance from x to y:  3.10322412983658
# L2 Distance from x to y:  3.0789608636681307
# L2 Distance from x to y:  3.1144823004794877
# L2 Distance from x to y:  3.3645207682521443
# L2 Distance from x to y:  1.9131126469708992
# L2 Distance from x to y:  3.029851481508623
# L2 Distance from x to y:  5.338539126015655
# L2 Distance from x to y:  4.180908992073374
# L2 Distance from x to y:  5.357238094391549
# L2 Distance from x to y:  4.708502946797421
# L2 Distance from x to y:  5.091168824543142
# L2 Distance from x to y:  6.159545437773796
# L2 Distance from x to y:  3.479942528261063
# L2 Distance from x to y:  5.686826883245173
# L2 Distance from x to y:  5.040833264451424
# L2 Distance from x to y:  5.747173218200404
# L2 Distance from x to y:  4.41927595879687
# L2 Distance from x to y:  4.521061822182926
# L2 Distance from x to y:  4.902040391510457
# L2 Distance from x to y:  4.134005321718878
# L2 Distance from x to y:  4.402272140611027
# L2 Distance from x to y:  4.68081189538738
# L2 Distance from x to y:  4.682947789587238
# L2 Distance from x to y:  6.369458375717672
# L2 Distance from x to y:  6.5314623171231725
# L2 Distance from x to y:  4.06201920231798
# L2 Distance from x to y:  5.1903757089443925
# L2 Distance from x to y:  4.0024992192379
# L2 Distance from x to y:  6.2617888817813085
# L2 Distance from x to y:  4.106093033529563
# L2 Distance from x to y:  5.042816673249187
# L2 Distance from x to y:  5.389805191284746
# L2 Distance from x to y:  3.9812058474788765
# L2 Distance from x to y:  4.031128874149275
# L2 Distance from x to y:  4.851803788283281
# L2 Distance from x to y:  5.158488150611572
# L2 Distance from x to y:  5.591958512006325
# L2 Distance from x to y:  6.154673021371647
# L2 Distance from x to y:  4.891829923454003
# L2 Distance from x to y:  4.168932717135165
# L2 Distance from x to y:  4.547526800360829
# L2 Distance from x to y:  5.860034129593443
# L2 Distance from x to y:  4.959838707054897
# L2 Distance from x to y:  4.650806381693394
# L2 Distance from x to y:  3.9153543900903784
# L2 Distance from x to y:  4.860041152089146
# L2 Distance from x to y:  5.072474741188959
# L2 Distance from x to y:  4.702127178203498
# L2 Distance from x to y:  4.180908992073374
# L2 Distance from x to y:  5.320714237769211
# L2 Distance from x to y:  5.206726418777926
# L2 Distance from x to y:  4.699999999999999
# L2 Distance from x to y:  4.249705872175156
# L2 Distance from x to y:  4.498888751680798
# L2 Distance from x to y:  4.718050444834179
# L2 Distance from x to y:  4.153311931459037
# L2 Distance from x to y:  0.509901951359278
# L2 Distance from x to y:  0.30000000000000016
# L2 Distance from x to y:  0.0
# L2 Distance from x to y:  0.24494897427831802
# L2 Distance from x to y:  0.5099019513592783
# L2 Distance from x to y:  1.0862780491200215
# L2 Distance from x to y:  0.264575131106459
# L2 Distance from x to y:  0.4123105625617658
# L2 Distance from x to y:  0.4358898943540674
# L2 Distance from x to y:  0.31622776601683805
# L2 Distance from x to y:  0.8831760866327848
# L2 Distance from x to y:  0.37416573867739394
# L2 Distance from x to y:  0.264575131106459
# L2 Distance from x to y:  0.5000000000000003
# L2 Distance from x to y:  1.3638181696985852
# L2 Distance from x to y:  1.5874507866387546
# L2 Distance from x to y:  1.0099504938362076
# L2 Distance from x to y:  0.5196152422706627
# L2 Distance from x to y:  1.236931687685298
# L2 Distance from x to y:  0.7549834435270745
# L2 Distance from x to y:  0.8306623862918076
# L2 Distance from x to y:  0.6999999999999996
# L2 Distance from x to y:  0.5099019513592785
# L2 Distance from x to y:  0.6480740698407855
# L2 Distance from x to y:  0.6403124237432846
# L2 Distance from x to y:  0.469041575982343
# L2 Distance from x to y:  0.5099019513592783
# L2 Distance from x to y:  0.6164414002968975
# L2 Distance from x to y:  0.547722557505166
# L2 Distance from x to y:  0.30000000000000004
# L2 Distance from x to y:  0.33166247903553997
# L2 Distance from x to y:  0.7810249675906655
# L2 Distance from x to y:  1.0535653752852736
# L2 Distance from x to y:  1.284523257866513
# L2 Distance from x to y:  0.31622776601683805
# L2 Distance from x to y:  0.31622776601683783
# L2 Distance from x to y:  0.8544003745317529
# L2 Distance from x to y:  0.31622776601683805
# L2 Distance from x to y:  0.3605551275463989
# L2 Distance from x to y:  0.4898979485566351
# L2 Distance from x to y:  0.4358898943540671
# L2 Distance from x to y:  0.9273618495495707
# L2 Distance from x to y:  0.2999999999999998
# L2 Distance from x to y:  0.6557438524301998
# L2 Distance from x to y:  0.9591663046625434
# L2 Distance from x to y:  0.264575131106459
# L2 Distance from x to y:  0.781024967590665
# L2 Distance from x to y:  0.14142135623730978
# L2 Distance from x to y:  0.8062257748298548
# L2 Distance from x to y:  0.3316624790355397
# L2 Distance from x to y:  4.27668095606862
# L2 Distance from x to y:  3.849675310984032
# L2 Distance from x to y:  4.415880433163924
# L2 Distance from x to y:  3.1543620591175014
# L2 Distance from x to y:  3.997499218261337
# L2 Distance from x to y:  3.551056180912941
# L2 Distance from x to y:  4.011234224026316
# L2 Distance from x to y:  2.3065125189341593
# L2 Distance from x to y:  3.974921382870358
# L2 Distance from x to y:  2.949576240750525
# L2 Distance from x to y:  2.6476404589747458
# L2 Distance from x to y:  3.402939905434711
# L2 Distance from x to y:  3.258834147360065
# L2 Distance from x to y:  3.8794329482541645
# L2 Distance from x to y:  2.7202941017470885
# L2 Distance from x to y:  3.8807215823864514
# L2 Distance from x to y:  3.5749125863438955
# L2 Distance from x to y:  3.152776554086889
# L2 Distance from x to y:  3.8961519477556315
# L2 Distance from x to y:  2.9782545223670858
# L2 Distance from x to y:  4.031128874149275
# L2 Distance from x to y:  3.258834147360065
# L2 Distance from x to y:  4.207136793592527
# L2 Distance from x to y:  3.8314488121336034
# L2 Distance from x to y:  3.6318039594669758
# L2 Distance from x to y:  3.8340579025361627
# L2 Distance from x to y:  4.2731721238443
# L2 Distance from x to y:  4.469899327725402
# L2 Distance from x to y:  3.702701716314724
# L2 Distance from x to y:  2.6153393661244047
# L2 Distance from x to y:  2.8879058156387303
# L2 Distance from x to y:  2.771281292110204
# L2 Distance from x to y:  3.0364452901377947
# L2 Distance from x to y:  4.282522621072771
# L2 Distance from x to y:  3.5298725189445586
# L2 Distance from x to y:  3.7322915213043046
# L2 Distance from x to y:  4.154515615568198
# L2 Distance from x to y:  3.766961640367473
# L2 Distance from x to y:  3.1464265445104544
# L2 Distance from x to y:  3.1032241298365806
# L2 Distance from x to y:  3.407345007480165
# L2 Distance from x to y:  3.7854986461495397
# L2 Distance from x to y:  3.1400636936215163
# L2 Distance from x to y:  2.3537204591879637
# L2 Distance from x to y:  3.2680269276736387
# L2 Distance from x to y:  3.232645975048923
# L2 Distance from x to y:  3.272613634390715
# L2 Distance from x to y:  3.5425979167836705
# L2 Distance from x to y:  2.085665361461421
# L2 Distance from x to y:  3.1953090617340916
# L2 Distance from x to y:  5.472659317004851
# L2 Distance from x to y:  4.334743360338648
# L2 Distance from x to y:  5.529014378711635
# L2 Distance from x to y:  4.868264577855234
# L2 Distance from x to y:  5.246903848937962
# L2 Distance from x to y:  6.336402764976355
# L2 Distance from x to y:  3.6083237105337433
# L2 Distance from x to y:  5.866003750424985
# L2 Distance from x to y:  5.224940191045253
# L2 Distance from x to y:  5.89406481131655
# L2 Distance from x to y:  4.573838650411709
# L2 Distance from x to y:  4.693612681080534
# L2 Distance from x to y:  5.06951674225463
# L2 Distance from x to y:  4.291852746774987
# L2 Distance from x to y:  4.544227107000705
# L2 Distance from x to y:  4.827007354458868
# L2 Distance from x to y:  4.8456165758342875
# L2 Distance from x to y:  6.520736154760443
# L2 Distance from x to y:  6.717886572427373
# L2 Distance from x to y:  4.250882261366457
# L2 Distance from x to y:  5.348831648126533
# L2 Distance from x to y:  4.1436698710201325
# L2 Distance from x to y:  6.44670458451448
# L2 Distance from x to y:  4.28135492572153
# L2 Distance from x to y:  5.194227565288221
# L2 Distance from x to y:  5.558776843874919
# L2 Distance from x to y:  4.149698784249286
# L2 Distance from x to y:  4.1856899072912706
# L2 Distance from x to y:  5.014977567247933
# L2 Distance from x to y:  5.338539126015656
# L2 Distance from x to y:  5.7775427302617155
# L2 Distance from x to y:  6.312685640834653
# L2 Distance from x to y:  5.053711507397311
# L2 Distance from x to y:  4.341658669218481
# L2 Distance from x to y:  4.716990566028302
# L2 Distance from x to y:  6.040695324215582
# L2 Distance from x to y:  5.0921508225896055
# L2 Distance from x to y:  4.806245936279167
# L2 Distance from x to y:  4.066939881532551
# L2 Distance from x to y:  5.026927491022723
# L2 Distance from x to y:  5.228766584960549
# L2 Distance from x to y:  4.868264577855234
# L2 Distance from x to y:  4.334743360338648
# L2 Distance from x to y:  5.475399528801528
# L2 Distance from x to y:  5.3535035257296695
# L2 Distance from x to y:  4.864154602806124
# L2 Distance from x to y:  4.430575583375145
# L2 Distance from x to y:  4.661544808322667
# L2 Distance from x to y:  4.848711168960263
# L2 Distance from x to y:  4.298837052040936
# L2 Distance from x to y:  0.648074069840786
# L2 Distance from x to y:  0.3316624790355407
# L2 Distance from x to y:  0.24494897427831802
# L2 Distance from x to y:  0.0
# L2 Distance from x to y:  0.6480740698407862
# L2 Distance from x to y:  1.1661903789690604
# L2 Distance from x to y:  0.33166247903553986
# L2 Distance from x to y:  0.5000000000000002
# L2 Distance from x to y:  0.2999999999999997
# L2 Distance from x to y:  0.3162277660168386
# L2 Distance from x to y:  1.0000000000000007
# L2 Distance from x to y:  0.3741657386773941
# L2 Distance from x to y:  0.26457513110645925
# L2 Distance from x to y:  0.519615242270663
# L2 Distance from x to y:  1.5297058540778354
# L2 Distance from x to y:  1.714642819948225
# L2 Distance from x to y:  1.1661903789690604
# L2 Distance from x to y:  0.6557438524302001
# L2 Distance from x to y:  1.3228756555322956
# L2 Distance from x to y:  0.8660254037844384
# L2 Distance from x to y:  0.8774964387392127
# L2 Distance from x to y:  0.806225774829855
# L2 Distance from x to y:  0.7071067811865476
# L2 Distance from x to y:  0.648074069840786
# L2 Distance from x to y:  0.5385164807134504
# L2 Distance from x to y:  0.42426406871192884
# L2 Distance from x to y:  0.5477225575051663
# L2 Distance from x to y:  0.7211102550927982
# L2 Distance from x to y:  0.6782329983125273
# L2 Distance from x to y:  0.17320508075688812
# L2 Distance from x to y:  0.22360679774997916
# L2 Distance from x to y:  0.8774964387392128
# L2 Distance from x to y:  1.1704699910719625
# L2 Distance from x to y:  1.424780684877501
# L2 Distance from x to y:  0.3162277660168386
# L2 Distance from x to y:  0.5099019513592788
# L2 Distance from x to y:  1.0049875621120892
# L2 Distance from x to y:  0.3162277660168386
# L2 Distance from x to y:  0.29999999999999954
# L2 Distance from x to y:  0.58309518948453
# L2 Distance from x to y:  0.6082762530298221
# L2 Distance from x to y:  0.8366600265340758
# L2 Distance from x to y:  0.29999999999999954
# L2 Distance from x to y:  0.7000000000000001
# L2 Distance from x to y:  0.9695359714832655
# L2 Distance from x to y:  0.26457513110645925
# L2 Distance from x to y:  0.8660254037844384
# L2 Distance from x to y:  0.14142135623730964
# L2 Distance from x to y:  0.9219544457292889
# L2 Distance from x to y:  0.4582575694955842
# L2 Distance from x to y:  4.177319714841086
# L2 Distance from x to y:  3.733630940518894
# L2 Distance from x to y:  4.305810028322198
# L2 Distance from x to y:  2.98496231131986
# L2 Distance from x to y:  3.8729833462074166
# L2 Distance from x to y:  3.3926390907374753
# L2 Distance from x to y:  3.889730067755345
# L2 Distance from x to y:  2.111871208194288
# L2 Distance from x to y:  3.8548670534792766
# L2 Distance from x to y:  2.778488797889961
# L2 Distance from x to y:  2.451530134426253
# L2 Distance from x to y:  3.2680269276736387
# L2 Distance from x to y:  3.108054053584011
# L2 Distance from x to y:  3.7376463182061515
# L2 Distance from x to y:  2.5806975801127883
# L2 Distance from x to y:  3.776241517699842
# L2 Distance from x to y:  3.420526275297414
# L2 Distance from x to y:  2.9999999999999996
# L2 Distance from x to y:  3.749666651850535
# L2 Distance from x to y:  2.816025568065745
# L2 Distance from x to y:  3.892300091205713
# L2 Distance from x to y:  3.1304951684997055
# L2 Distance from x to y:  4.06201920231798
# L2 Distance from x to y:  3.685105154537656
# L2 Distance from x to y:  3.511409973215888
# L2 Distance from x to y:  3.722902093797257
# L2 Distance from x to y:  4.154515615568198
# L2 Distance from x to y:  4.349712634186309
# L2 Distance from x to y:  3.5623026261113755
# L2 Distance from x to y:  2.469817807045694
# L2 Distance from x to y:  2.7202941017470885
# L2 Distance from x to y:  2.6038433132583076
# L2 Distance from x to y:  2.891366458960192
# L2 Distance from x to y:  4.127953488110059
# L2 Distance from x to y:  3.3674916480965473
# L2 Distance from x to y:  3.606937759374287
# L2 Distance from x to y:  4.042276586281548
# L2 Distance from x to y:  3.6262928728937496
# L2 Distance from x to y:  2.9966648127543394
# L2 Distance from x to y:  2.9376861643136762
# L2 Distance from x to y:  3.235737937472688
# L2 Distance from x to y:  3.6482872693909396
# L2 Distance from x to y:  2.989983277545211
# L2 Distance from x to y:  2.1633307652783933
# L2 Distance from x to y:  3.108054053584011
# L2 Distance from x to y:  3.083828789021855
# L2 Distance from x to y:  3.1224989991991996
# L2 Distance from x to y:  3.4132096331752027
# L2 Distance from x to y:  1.915724406066802
# L2 Distance from x to y:  3.0446674695276656
# L2 Distance from x to y:  5.33572862878164
# L2 Distance from x to y:  4.177319714841084
# L2 Distance from x to y:  5.406477596365309
# L2 Distance from x to y:  4.722287581247038
# L2 Distance from x to y:  5.109794516416487
# L2 Distance from x to y:  6.215303693304133
# L2 Distance from x to y:  3.420526275297414
# L2 Distance from x to y:  5.738466694161429
# L2 Distance from x to y:  5.081338406365
# L2 Distance from x to y:  5.784461945591827
# L2 Distance from x to y:  4.451965857910413
# L2 Distance from x to y:  4.553020975132885
# L2 Distance from x to y:  4.9457052075512955
# L2 Distance from x to y:  4.1303752856126765
# L2 Distance from x to y:  4.396589587396122
# L2 Distance from x to y:  4.701063709417263
# L2 Distance from x to y:  4.709564735726647
# L2 Distance from x to y:  6.414047084329831
# L2 Distance from x to y:  6.590144156238162
# L2 Distance from x to y:  4.0877866871939394
# L2 Distance from x to y:  5.229722745997153
# L2 Distance from x to y:  3.98622628559895
# L2 Distance from x to y:  6.3229739838148955
# L2 Distance from x to y:  4.1436698710201325
# L2 Distance from x to y:  5.06951674225463
# L2 Distance from x to y:  5.4387498563548595
# L2 Distance from x to y:  4.012480529547776
# L2 Distance from x to y:  4.047221268969612
# L2 Distance from x to y:  4.873397172404482
# L2 Distance from x to y:  5.2172789842982334
# L2 Distance from x to y:  5.655086206239477
# L2 Distance from x to y:  6.215303693304134
# L2 Distance from x to y:  4.913247398615299
# L2 Distance from x to y:  4.198809355043403
# L2 Distance from x to y:  4.55521678957215
# L2 Distance from x to y:  5.932115979985556
# L2 Distance from x to y:  4.962862077471023
# L2 Distance from x to y:  4.669047011971501
# L2 Distance from x to y:  3.9268307832143723
# L2 Distance from x to y:  4.9101934788763675
# L2 Distance from x to y:  5.104899607240087
# L2 Distance from x to y:  4.760252094164762
# L2 Distance from x to y:  4.177319714841084
# L2 Distance from x to y:  5.349766350038103
# L2 Distance from x to y:  5.232590180780452
# L2 Distance from x to y:  4.7455242070818695
# L2 Distance from x to y:  4.288356328478313
# L2 Distance from x to y:  4.533210782657255
# L2 Distance from x to y:  4.719110085598767
# L2 Distance from x to y:  4.149698784249286
# L2 Distance from x to y:  0.1414213562373093
# L2 Distance from x to y:  0.608276253029822
# L2 Distance from x to y:  0.5099019513592783
# L2 Distance from x to y:  0.6480740698407862
# L2 Distance from x to y:  0.0
# L2 Distance from x to y:  0.6164414002968979
# L2 Distance from x to y:  0.4582575694955844
# L2 Distance from x to y:  0.22360679774997916
# L2 Distance from x to y:  0.9219544457292886
# L2 Distance from x to y:  0.529150262212918
# L2 Distance from x to y:  0.42426406871192884
# L2 Distance from x to y:  0.3464101615137758
# L2 Distance from x to y:  0.640312423743285
# L2 Distance from x to y:  0.9746794344808964
# L2 Distance from x to y:  0.9165151389911678
# L2 Distance from x to y:  1.086278049120022
# L2 Distance from x to y:  0.5477225575051663
# L2 Distance from x to y:  0.17320508075688756
# L2 Distance from x to y:  0.7937253933193773
# L2 Distance from x to y:  0.26457513110645875
# L2 Distance from x to y:  0.5385164807134507
# L2 Distance from x to y:  0.264575131106459
# L2 Distance from x to y:  0.5656854249492381
# L2 Distance from x to y:  0.5291502622129183
# L2 Distance from x to y:  0.574456264653803
# L2 Distance from x to y:  0.632455532033676
# L2 Distance from x to y:  0.3464101615137757
# L2 Distance from x to y:  0.24494897427831802
# L2 Distance from x to y:  0.2828427124746193
# L2 Distance from x to y:  0.5385164807134504
# L2 Distance from x to y:  0.5744562646538031
# L2 Distance from x to y:  0.5000000000000003
# L2 Distance from x to y:  0.5567764362830019
# L2 Distance from x to y:  0.7810249675906655
# L2 Distance from x to y:  0.529150262212918
# L2 Distance from x to y:  0.4472135954999578
# L2 Distance from x to y:  0.5196152422706631
# L2 Distance from x to y:  0.529150262212918
# L2 Distance from x to y:  0.854400374531753
# L2 Distance from x to y:  0.24494897427831785
# L2 Distance from x to y:  0.17320508075688767
# L2 Distance from x to y:  1.4000000000000001
# L2 Distance from x to y:  0.7280109889280515
# L2 Distance from x to y:  0.4582575694955841
# L2 Distance from x to y:  0.5830951894845299
# L2 Distance from x to y:  0.640312423743285
# L2 Distance from x to y:  0.2999999999999998
# L2 Distance from x to y:  0.5656854249492381
# L2 Distance from x to y:  0.3316624790355399
# L2 Distance from x to y:  0.30000000000000027
# L2 Distance from x to y:  4.060788100849391
# L2 Distance from x to y:  3.663331816802841
# L2 Distance from x to y:  4.219004621945798
# L2 Distance from x to y:  3.148015247739439
# L2 Distance from x to y:  3.8496753109840314
# L2 Distance from x to y:  3.4568772034887214
# L2 Distance from x to y:  3.824918299781056
# L2 Distance from x to y:  2.387467277262665
# L2 Distance from x to y:  3.807886552931954
# L2 Distance from x to y:  2.9223278392404914
# L2 Distance from x to y:  2.7586228448267445
# L2 Distance from x to y:  3.2710854467592254
# L2 Distance from x to y:  3.2186953878862163
# L2 Distance from x to y:  3.7456641600656084
# L2 Distance from x to y:  2.6267851073127395
# L2 Distance from x to y:  3.685105154537656
# L2 Distance from x to y:  3.4669871646719432
# L2 Distance from x to y:  3.0626785662227105
# L2 Distance from x to y:  3.8340579025361627
# L2 Distance from x to y:  2.9376861643136762
# L2 Distance from x to y:  3.8845849199110063
# L2 Distance from x to y:  3.1336879231984796
# L2 Distance from x to y:  4.1036569057366385
# L2 Distance from x to y:  3.706750598570128
# L2 Distance from x to y:  3.474190553208042
# L2 Distance from x to y:  3.655133376499413
# L2 Distance from x to y:  4.1085277168348275
# L2 Distance from x to y:  4.296510211788167
# L2 Distance from x to y:  3.5763109484495335
# L2 Distance from x to y:  2.5573423705088847
# L2 Distance from x to y:  2.874021572639983
# L2 Distance from x to y:  2.7604347483684526
# L2 Distance from x to y:  2.949576240750525
# L2 Distance from x to y:  4.178516483155235
# L2 Distance from x to y:  3.438022687534217
# L2 Distance from x to y:  3.551056180912941
# L2 Distance from x to y:  3.9648455203198023
# L2 Distance from x to y:  3.686461718233353
# L2 Distance from x to y:  3.036445290137795
# L2 Distance from x to y:  3.0708305065568178
# L2 Distance from x to y:  3.354101966249685
# L2 Distance from x to y:  3.640054944640259
# L2 Distance from x to y:  3.0659419433511785
# L2 Distance from x to y:  2.4372115213907883
# L2 Distance from x to y:  3.1968734726291563
# L2 Distance from x to y:  3.1128764832546763
# L2 Distance from x to y:  3.1670175244226235
# L2 Distance from x to y:  3.398529093593286
# L2 Distance from x to y:  2.142428528562855
# L2 Distance from x to y:  3.10322412983658
# L2 Distance from x to y:  5.313191131514092
# L2 Distance from x to y:  4.246174749112429
# L2 Distance from x to y:  5.350700888668698
# L2 Distance from x to y:  4.730750469005947
# L2 Distance from x to y:  5.096076922496363
# L2 Distance from x to y:  6.14573022512378
# L2 Distance from x to y:  3.6166282640050254
# L2 Distance from x to y:  5.68770604022395
# L2 Distance from x to y:  5.10098029794274
# L2 Distance from x to y:  5.67626637852735
# L2 Distance from x to y:  4.397726685459204
# L2 Distance from x to y:  4.568369512200168
# L2 Distance from x to y:  4.901020301937138
# L2 Distance from x to y:  4.230839160261236
# L2 Distance from x to y:  4.450842616853577
# L2 Distance from x to y:  4.662617290749906
# L2 Distance from x to y:  4.688283267892417
# L2 Distance from x to y:  6.278534860936905
# L2 Distance from x to y:  6.553624951124378
# L2 Distance from x to y:  4.196427051671458
# L2 Distance from x to y:  5.164300533470143
# L2 Distance from x to y:  4.060788100849391
# L2 Distance from x to y:  6.265780079128217
# L2 Distance from x to y:  4.160528812542944
# L2 Distance from x to y:  5.007993610219566
# L2 Distance from x to y:  5.359104402789705
# L2 Distance from x to y:  4.024922359499622
# L2 Distance from x to y:  4.047221268969612
# L2 Distance from x to y:  4.8836461788299115
# L2 Distance from x to y:  5.149757275833493
# L2 Distance from x to y:  5.601785429664367
# L2 Distance from x to y:  6.057227088363124
# L2 Distance from x to y:  4.923413450036468
# L2 Distance from x to y:  4.208325082500163
# L2 Distance from x to y:  4.6141087980237305
# L2 Distance from x to y:  5.843800133474791
# L2 Distance from x to y:  4.920365840057017
# L2 Distance from x to y:  4.645427859734774
# L2 Distance from x to y:  3.9344631145812
# L2 Distance from x to y:  4.844584605515729
# L2 Distance from x to y:  5.061620293937505
# L2 Distance from x to y:  4.686149805543992
# L2 Distance from x to y:  4.246174749112429
# L2 Distance from x to y:  5.2971690552596105
# L2 Distance from x to y:  5.173006862551025
# L2 Distance from x to y:  4.701063709417263
# L2 Distance from x to y:  4.330127018922194
# L2 Distance from x to y:  4.504442251822083
# L2 Distance from x to y:  4.678675026115834
# L2 Distance from x to y:  4.173727350941841
# L2 Distance from x to y:  0.6164414002968979
# L2 Distance from x to y:  1.0908712114635715
# L2 Distance from x to y:  1.0862780491200215
# L2 Distance from x to y:  1.1661903789690604
# L2 Distance from x to y:  0.6164414002968979
# L2 Distance from x to y:  0.0
# L2 Distance from x to y:  0.9949874371066205
# L2 Distance from x to y:  0.7000000000000002
# L2 Distance from x to y:  1.4594519519326423
# L2 Distance from x to y:  1.0099504938362076
# L2 Distance from x to y:  0.3464101615137753
# L2 Distance from x to y:  0.8124038404635965
# L2 Distance from x to y:  1.1618950038622253
# L2 Distance from x to y:  1.5716233645501714
# L2 Distance from x to y:  0.6782329983125266
# L2 Distance from x to y:  0.6164414002968979
# L2 Distance from x to y:  0.3999999999999999
# L2 Distance from x to y:  0.5916079783099619
# L2 Distance from x to y:  0.33166247903553986
# L2 Distance from x to y:  0.38729833462074226
# L2 Distance from x to y:  0.5385164807134505
# L2 Distance from x to y:  0.41231056256176646
# L2 Distance from x to y:  1.1224972160321829
# L2 Distance from x to y:  0.6782329983125271
# L2 Distance from x to y:  0.8306623862918079
# L2 Distance from x to y:  1.0099504938362078
# L2 Distance from x to y:  0.6480740698407862
# L2 Distance from x to y:  0.529150262212918
# L2 Distance from x to y:  0.6480740698407862
# L2 Distance from x to y:  1.014889156509222
# L2 Distance from x to y:  1.0246950765959602
# L2 Distance from x to y:  0.5385164807134504
# L2 Distance from x to y:  0.45825756949558394
# L2 Distance from x to y:  0.4795831523312721
# L2 Distance from x to y:  1.0099504938362076
# L2 Distance from x to y:  0.9695359714832658
# L2 Distance from x to y:  0.6082762530298218
# L2 Distance from x to y:  1.0099504938362076
# L2 Distance from x to y:  1.4177446878757824
# L2 Distance from x to y:  0.6480740698407863
# L2 Distance from x to y:  0.7000000000000001
# L2 Distance from x to y:  1.881488772222678
# L2 Distance from x to y:  1.2999999999999998
# L2 Distance from x to y:  0.608276253029822
# L2 Distance from x to y:  0.3741657386773947
# L2 Distance from x to y:  1.1269427669584646
# L2 Distance from x to y:  0.38729833462074226
# L2 Distance from x to y:  1.1224972160321829
# L2 Distance from x to y:  0.36055512754639896
# L2 Distance from x to y:  0.8062257748298551
# L2 Distance from x to y:  3.6124783736376886
# L2 Distance from x to y:  3.246536616149585
# L2 Distance from x to y:  3.786819245752298
# L2 Distance from x to y:  2.9444863728670914
# L2 Distance from x to y:  3.4698703145794942
# L2 Distance from x to y:  3.1543620591175006
# L2 Distance from x to y:  3.407345007480164
# L2 Distance from x to y:  2.328089345364563
# L2 Distance from x to y:  3.4146742157927736
# L2 Distance from x to y:  2.705549851693737
# L2 Distance from x to y:  2.7147743920996454
# L2 Distance from x to y:  2.9189039038652846
# L2 Distance from x to y:  2.983286778035259
# L2 Distance from x to y:  3.3896902513356584
# L2 Distance from x to y:  2.3366642891095846
# L2 Distance from x to y:  3.258834147360065
# L2 Distance from x to y:  3.1464265445104544
# L2 Distance from x to y:  2.77848879788996
# L2 Distance from x to y:  3.5468295701936396
# L2 Distance from x to y:  2.7073972741361767
# L2 Distance from x to y:  3.5085609585697664
# L2 Distance from x to y:  2.792848008753788
# L2 Distance from x to y:  3.770941526992961
# L2 Distance from x to y:  3.3674916480965473
# L2 Distance from x to y:  3.0935416596516037
# L2 Distance from x to y:  3.246536616149585
# L2 Distance from x to y:  3.7121422386541165
# L2 Distance from x to y:  3.883297567789519
# L2 Distance from x to y:  3.2264531609803355
# L2 Distance from x to y:  2.3194827009486403
# L2 Distance from x to y:  2.6758176320519302
# L2 Distance from x to y:  2.5729360660537215
# L2 Distance from x to y:  2.660826939130014
# L2 Distance from x to y:  3.8470768123342687
# L2 Distance from x to y:  3.1400636936215163
# L2 Distance from x to y:  3.144837038703278
# L2 Distance from x to y:  3.5411862419251547
# L2 Distance from x to y:  3.38673884437522
# L2 Distance from x to y:  2.7239676943752467
# L2 Distance from x to y:  2.840774542268358
# L2 Distance from x to y:  3.10322412983658
# L2 Distance from x to y:  3.2726136343907135
# L2 Distance from x to y:  2.78926513619627
# L2 Distance from x to y:  2.3748684174075834
# L2 Distance from x to y:  2.9223278392404914
# L2 Distance from x to y:  2.7910571473905725
# L2 Distance from x to y:  2.8548204847240397
# L2 Distance from x to y:  3.0347981810987035
# L2 Distance from x to y:  2.0566963801203135
# L2 Distance from x to y:  2.8053520278211073
# L2 Distance from x to y:  4.906118628814432
# L2 Distance from x to y:  3.9255572852781038
# L2 Distance from x to y:  4.922397789695586
# L2 Distance from x to y:  4.356604182158392
# L2 Distance from x to y:  4.697871858618538
# L2 Distance from x to y:  5.705260730238364
# L2 Distance from x to y:  3.4263683398023628
# L2 Distance from x to y:  5.265928218272634
# L2 Distance from x to y:  4.734976240700686
# L2 Distance from x to y:  5.205766033928147
# L2 Distance from x to y:  3.977436360270268
# L2 Distance from x to y:  4.201190307520001
# L2 Distance from x to y:  4.483302354291979
# L2 Distance from x to y:  3.937003937005905
# L2 Distance from x to y:  4.114608122288196
# L2 Distance from x to y:  4.249705872175156
# L2 Distance from x to y:  4.291852746774986
# L2 Distance from x to y:  5.791372894228103
# L2 Distance from x to y:  6.134329629226
# L2 Distance from x to y:  3.9179076048319463
# L2 Distance from x to y:  4.727578661429125
# L2 Distance from x to y:  3.748332962798263
# L2 Distance from x to y:  5.8360945845659495
# L2 Distance from x to y:  3.8013155617496426
# L2 Distance from x to y:  4.57602447545902
# L2 Distance from x to y:  4.917316341257699
# L2 Distance from x to y:  3.66333181680284
# L2 Distance from x to y:  3.6742346141747673
# L2 Distance from x to y:  4.506661735697499
# L2 Distance from x to y:  4.722287581247038
# L2 Distance from x to y:  5.1788029504896205
# L2 Distance from x to y:  5.5596762495670555
# L2 Distance from x to y:  4.545327270945404
# L2 Distance from x to y:  3.8457769046058816
# L2 Distance from x to y:  4.288356328478312
# L2 Distance from x to y:  5.3916602266834275
# L2 Distance from x to y:  4.502221673796171
# L2 Distance from x to y:  4.24735211631906
# L2 Distance from x to y:  3.569313659514949
# L2 Distance from x to y:  4.412482294582042
# L2 Distance from x to y:  4.641120554348917
# L2 Distance from x to y:  4.249705872175155
# L2 Distance from x to y:  3.9255572852781038
# L2 Distance from x to y:  4.868264577855234
# L2 Distance from x to y:  4.739198244429114
# L2 Distance from x to y:  4.28485705712571
# L2 Distance from x to y:  3.9887341350358256
# L2 Distance from x to y:  4.102438299353203
# L2 Distance from x to y:  4.264973622427225
# L2 Distance from x to y:  3.818376618407356
# L2 Distance from x to y:  0.5196152422706632
# L2 Distance from x to y:  0.5099019513592788
# L2 Distance from x to y:  0.264575131106459
# L2 Distance from x to y:  0.33166247903553986
# L2 Distance from x to y:  0.4582575694955844
# L2 Distance from x to y:  0.9949874371066205
# L2 Distance from x to y:  0.0
# L2 Distance from x to y:  0.42426406871192884
# L2 Distance from x to y:  0.5477225575051659
# L2 Distance from x to y:  0.4795831523312723
# L2 Distance from x to y:  0.8660254037844394
# L2 Distance from x to y:  0.3000000000000002
# L2 Distance from x to y:  0.4898979485566356
# L2 Distance from x to y:  0.6164414002968974
# L2 Distance from x to y:  1.3601470508735445
# L2 Distance from x to y:  1.4933184523068084
# L2 Distance from x to y:  0.9539392014169462
# L2 Distance from x to y:  0.5099019513592785
# L2 Distance from x to y:  1.2083045973594577
# L2 Distance from x to y:  0.648074069840786
# L2 Distance from x to y:  0.8602325267042633
# L2 Distance from x to y:  0.6000000000000002
# L2 Distance from x to y:  0.45825756949558394
# L2 Distance from x to y:  0.6244997998398398
# L2 Distance from x to y:  0.5477225575051662
# L2 Distance from x to y:  0.6082762530298222
# L2 Distance from x to y:  0.4582575694955844
# L2 Distance from x to y:  0.6244997998398404
# L2 Distance from x to y:  0.6082762530298225
# L2 Distance from x to y:  0.31622776601683805
# L2 Distance from x to y:  0.42426406871192857
# L2 Distance from x to y:  0.8124038404635967
# L2 Distance from x to y:  0.948683298050514
# L2 Distance from x to y:  1.2083045973594577
# L2 Distance from x to y:  0.4795831523312723
# L2 Distance from x to y:  0.5000000000000002
# L2 Distance from x to y:  0.9165151389911683
# L2 Distance from x to y:  0.4795831523312723
# L2 Distance from x to y:  0.46904157598234253
# L2 Distance from x to y:  0.5196152422706632
# L2 Distance from x to y:  0.42426406871192884
# L2 Distance from x to y:  1.1090536506409419
# L2 Distance from x to y:  0.3162277660168373
# L2 Distance from x to y:  0.5477225575051664
# L2 Distance from x to y:  0.818535277187245
# L2 Distance from x to y:  0.4472135954999579
# L2 Distance from x to y:  0.6782329983125268
# L2 Distance from x to y:  0.22360679774997871
# L2 Distance from x to y:  0.7745966692414836
# L2 Distance from x to y:  0.42426406871192884
# L2 Distance from x to y:  4.230839160261237
# L2 Distance from x to y:  3.7854986461495406
# L2 Distance from x to y:  4.366921112179611
# L2 Distance from x to y:  3.1272991542223783
# L2 Distance from x to y:  3.9560080889704965
# L2 Distance from x to y:  3.48998567332303
# L2 Distance from x to y:  3.9344631145812006
# L2 Distance from x to y:  2.2781571499789037
# L2 Distance from x to y:  3.935733730830885
# L2 Distance from x to y:  2.882707061079915
# L2 Distance from x to y:  2.649528259898354
# L2 Distance from x to y:  3.336165463522456
# L2 Distance from x to y:  3.263433774416144
# L2 Distance from x to y:  3.82099463490856
# L2 Distance from x to y:  2.6627053911388696
# L2 Distance from x to y:  3.8353617821530217
# L2 Distance from x to y:  3.4942810419312296
# L2 Distance from x to y:  3.1160872901765764
# L2 Distance from x to y:  3.879432948254165
# L2 Distance from x to y:  2.9495762407505253
# L2 Distance from x to y:  3.9420806688854046
# L2 Distance from x to y:  3.2202484376209237
# L2 Distance from x to y:  4.170131892398609
# L2 Distance from x to y:  3.782856063875548
# L2 Distance from x to y:  3.5916569992135945
# L2 Distance from x to y:  3.7907782842049733
# L2 Distance from x to y:  4.2391036788453285
# L2 Distance from x to y:  4.4147480109288235
# L2 Distance from x to y:  3.641428291206625
# L2 Distance from x to y:  2.598076211353316
# L2 Distance from x to y:  2.8653097563788807
# L2 Distance from x to y:  2.7549954627911823
# L2 Distance from x to y:  2.99833287011299
# L2 Distance from x to y:  4.222558466143482
# L2 Distance from x to y:  3.4423828956117015
# L2 Distance from x to y:  3.641428291206625
# L2 Distance from x to y:  4.102438299353204
# L2 Distance from x to y:  3.754996671103718
# L2 Distance from x to y:  3.074085229787879
# L2 Distance from x to y:  3.062678566222711
# L2 Distance from x to y:  3.3555923471125038
# L2 Distance from x to y:  3.7229020937972566
# L2 Distance from x to y:  3.1064449134018135
# L2 Distance from x to y:  2.3388031127053
# L2 Distance from x to y:  3.2140317359976396
# L2 Distance from x to y:  3.1654383582688834
# L2 Distance from x to y:  3.209361307176243
# L2 Distance from x to y:  3.4957116585897072
# L2 Distance from x to y:  2.0639767440550294
# L2 Distance from x to y:  3.1400636936215163
# L2 Distance from x to y:  5.375872022286245
# L2 Distance from x to y:  4.263801121065568
# L2 Distance from x to y:  5.468089245796926
# L2 Distance from x to y:  4.79895822028073
# L2 Distance from x to y:  5.171073389539159
# L2 Distance from x to y:  6.280127387243032
# L2 Distance from x to y:  3.531288716601915
# L2 Distance from x to y:  5.813776741499454
# L2 Distance from x to y:  5.179768334587948
# L2 Distance from x to y:  5.807753438292641
# L2 Distance from x to y:  4.497777228809804
# L2 Distance from x to y:  4.636809247747852
# L2 Distance from x to y:  5.004997502496879
# L2 Distance from x to y:  4.22729227756965
# L2 Distance from x to y:  4.460941604639093
# L2 Distance from x to y:  4.742362280551751
# L2 Distance from x to y:  4.778074926160116
# L2 Distance from x to y:  6.439720490828776
# L2 Distance from x to y:  6.670832032063167
# L2 Distance from x to y:  4.219004621945797
# L2 Distance from x to y:  5.274466797696238
# L2 Distance from x to y:  4.06201920231798
# L2 Distance from x to y:  6.399218702310463
# L2 Distance from x to y:  4.228474902373195
# L2 Distance from x to y:  5.113707070218239
# L2 Distance from x to y:  5.496362433464518
# L2 Distance from x to y:  4.090232267243512
# L2 Distance from x to y:  4.112177038990418
# L2 Distance from x to y:  4.947726750741192
# L2 Distance from x to y:  5.288667128870942
# L2 Distance from x to y:  5.73149195236284
# L2 Distance from x to y:  6.240192304729078
# L2 Distance from x to y:  4.984977432245807
# L2 Distance from x to y:  4.287190222045203
# L2 Distance from x to y:  4.662617290749906
# L2 Distance from x to y:  5.988321968631946
# L2 Distance from x to y:  4.993996395673508
# L2 Distance from x to y:  4.731807265728392
# L2 Distance from x to y:  3.9912404086950213
# L2 Distance from x to y:  4.961854492022112
# L2 Distance from x to y:  5.1526692111953
# L2 Distance from x to y:  4.803123983409131
# L2 Distance from x to y:  4.263801121065568
# L2 Distance from x to y:  5.397221507405454
# L2 Distance from x to y:  5.26782687642637
# L2 Distance from x to y:  4.796873982084583
# L2 Distance from x to y:  4.384062043356595
# L2 Distance from x to y:  4.5934736311423405
# L2 Distance from x to y:  4.749736834815167
# L2 Distance from x to y:  4.217819341792628
# L2 Distance from x to y:  0.17320508075688762
# L2 Distance from x to y:  0.42426406871192834
# L2 Distance from x to y:  0.4123105625617658
# L2 Distance from x to y:  0.5000000000000002
# L2 Distance from x to y:  0.22360679774997916
# L2 Distance from x to y:  0.7000000000000002
# L2 Distance from x to y:  0.42426406871192884
# L2 Distance from x to y:  0.0
# L2 Distance from x to y:  0.7874007874011809
# L2 Distance from x to y:  0.3316624790355397
# L2 Distance from x to y:  0.5000000000000004
# L2 Distance from x to y:  0.22360679774997916
# L2 Distance from x to y:  0.469041575982343
# L2 Distance from x to y:  0.9055385138137417
# L2 Distance from x to y:  1.0440306508910548
# L2 Distance from x to y:  1.2369316876852987
# L2 Distance from x to y:  0.7000000000000002
# L2 Distance from x to y:  0.1999999999999999
# L2 Distance from x to y:  0.8366600265340757
# L2 Distance from x to y:  0.4242640687119283
# L2 Distance from x to y:  0.4472135954999582
# L2 Distance from x to y:  0.3741657386773943
# L2 Distance from x to y:  0.6708203932499371
# L2 Distance from x to y:  0.3872983346207416
# L2 Distance from x to y:  0.4472135954999579
# L2 Distance from x to y:  0.41231056256176596
# L2 Distance from x to y:  0.22360679774997902
# L2 Distance from x to y:  0.22360679774997916
# L2 Distance from x to y:  0.22360679774997916
# L2 Distance from x to y:  0.37416573867739383
# L2 Distance from x to y:  0.3741657386773941
# ...
# L2 Distance from x to y:  1.5620499351813306
# L2 Distance from x to y:  0.9380831519646864
# L2 Distance from x to y:  1.652271164185831
# L2 Distance from x to y:  2.711088342345192
# L2 Distance from x to y:  1.5459624833740306
# L2 Distance from x to y:  1.5099668870541498
# L2 Distance from x to y:  1.4628738838327793
# L2 Distance from x to y:  1.1832159566199234
# L2 Distance from x to y:  2.8035691537752374
# L2 Distance from x to y:  1.5427248620541516
# L2 Distance from x to y:  1.0099504938362076
# L2 Distance from x to y:  0.7745966692414836
# L2 Distance from x to y:  0.9273618495495703
# L2 Distance from x to y:  0.49999999999999967
# L2 Distance from x to y:  0.6324555320336757
# L2 Distance from x to y:  1.7832554500127002
# L2 Distance from x to y:  1.8411952639521967
# L2 Distance from x to y:  1.3784048752090219
# L2 Distance from x to y:  0.8306623862918073
# L2 Distance from x to y:  1.382027496108525
# L2 Distance from x to y:  0.22360679774997935
# L2 Distance from x to y:  0.34641016151377513
# L2 Distance from x to y:  0.4358898943540671
# L2 Distance from x to y:  0.9643650760992953
# L2 Distance from x to y:  0.8366600265340758
# L2 Distance from x to y:  0.3872983346207415
# L2 Distance from x to y:  0.3605551275463988
# L2 Distance from x to y:  2.090454496036687
# L2 Distance from x to y:  2.14009345590327
# L2 Distance from x to y:  1.0862780491200215
# L2 Distance from x to y:  0.7348469228349536
# L2 Distance from x to y:  0.9695359714832661
# L2 Distance from x to y:  1.9313207915827968
# L2 Distance from x to y:  0.5099019513592783
# L2 Distance from x to y:  0.6244997998398398
# L2 Distance from x to y:  1.1
# L2 Distance from x to y:  0.5744562646538031
# L2 Distance from x to y:  0.5385164807134505
# L2 Distance from x to y:  0.46904157598234253
# L2 Distance from x to y:  1.004987562112089
# L2 Distance from x to y:  1.2922847983320085
# L2 Distance from x to y:  2.0099751242241783
# L2 Distance from x to y:  0.49999999999999967
# L2 Distance from x to y:  0.5830951894845302
# L2 Distance from x to y:  0.9165151389911679
# L2 Distance from x to y:  1.5297058540778352
# L2 Distance from x to y:  0.7211102550927975
# L2 Distance from x to y:  0.3872983346207415
# L2 Distance from x to y:  0.670820393249937
# L2 Distance from x to y:  0.46904157598234336
# L2 Distance from x to y:  0.6082762530298217
# L2 Distance from x to y:  0.5196152422706635
# L2 Distance from x to y:  0.7745966692414836
# L2 Distance from x to y:  0.8426149773176359
# L2 Distance from x to y:  0.7937253933193772
# L2 Distance from x to y:  0.3605551275463989
# L2 Distance from x to y:  0.5830951894845302
# L2 Distance from x to y:  0.0
# L2 Distance from x to y:  0.6164414002968975
# L2 Distance from x to y:  0.6403124237432847
# L2 Distance from x to y:  4.650806381693394
# L2 Distance from x to y:  4.718050444834179
# L2 Distance from x to y:  4.848711168960263
# L2 Distance from x to y:  4.719110085598767
# L2 Distance from x to y:  4.678675026115834
# L2 Distance from x to y:  4.264973622427225
# L2 Distance from x to y:  4.749736834815167
# L2 Distance from x to y:  4.589117562233507
# L2 Distance from x to y:  4.888762624632126
# L2 Distance from x to y:  4.672258554489467
# L2 Distance from x to y:  4.511097427455985
# L2 Distance from x to y:  4.561797891182818
# L2 Distance from x to y:  4.791659420284375
# L2 Distance from x to y:  5.205766033928149
# L2 Distance from x to y:  4.750789408087881
# L2 Distance from x to y:  4.479955356920424
# L2 Distance from x to y:  4.616275555033517
# L2 Distance from x to y:  4.606517122512408
# L2 Distance from x to y:  4.254409477236529
# L2 Distance from x to y:  4.536518488885503
# L2 Distance from x to y:  4.328972164382673
# L2 Distance from x to y:  4.485532298401162
# L2 Distance from x to y:  5.135172830587107
# L2 Distance from x to y:  4.260281680828159
# L2 Distance from x to y:  4.315089802078284
# L2 Distance from x to y:  4.522167621838006
# L2 Distance from x to y:  4.4147480109288235
# L2 Distance from x to y:  4.5420259796703055
# L2 Distance from x to y:  4.62709412050371
# L2 Distance from x to y:  4.59782557302906
# L2 Distance from x to y:  4.571651780264984
# L2 Distance from x to y:  4.411349000022556
# L2 Distance from x to y:  4.641120554348918
# L2 Distance from x to y:  4.641120554348917
# L2 Distance from x to y:  4.672258554489467
# L2 Distance from x to y:  4.850773134253961
# L2 Distance from x to y:  4.660472079092418
# L2 Distance from x to y:  4.672258554489467
# L2 Distance from x to y:  4.961854492022112
# L2 Distance from x to y:  4.563989482897611
# L2 Distance from x to y:  4.71805044483418
# L2 Distance from x to y:  4.990991885387113
# L2 Distance from x to y:  4.949747468305833
# L2 Distance from x to y:  4.3335897360040905
# L2 Distance from x to y:  4.150903516103452
# L2 Distance from x to y:  4.703190406521939
# L2 Distance from x to y:  4.496665431183423
# L2 Distance from x to y:  4.796873982084582
# L2 Distance from x to y:  4.529900661162451
# L2 Distance from x to y:  4.675467891024383
# L2 Distance from x to y:  1.4071247279470287
# L2 Distance from x to y:  1.2369316876852983
# L2 Distance from x to y:  1.212435565298214
# L2 Distance from x to y:  2.1587033144922905
# L2 Distance from x to y:  1.315294643796591
# L2 Distance from x to y:  1.5556349186104046
# L2 Distance from x to y:  0.9999999999999999
# L2 Distance from x to y:  2.964793416074719
# L2 Distance from x to y:  1.4317821063276355
# L2 Distance from x to y:  2.1330729007701543
# L2 Distance from x to y:  2.9495762407505253
# L2 Distance from x to y:  1.5264337522473748
# L2 Distance from x to y:  2.264950330581225
# L2 Distance from x to y:  1.2489995996796797
# L2 Distance from x to y:  2.202271554554524
# L2 Distance from x to y:  1.4662878298615178
# L2 Distance from x to y:  1.4035668847618203
# L2 Distance from x to y:  2.0074859899884734
# L2 Distance from x to y:  1.7
# L2 Distance from x to y:  2.2045407685048604
# L2 Distance from x to y:  0.8602325267042628
# L2 Distance from x to y:  1.824828759089466
# L2 Distance from x to y:  1.3076696830622019
# L2 Distance from x to y:  1.438749456993816
# L2 Distance from x to y:  1.58113883008419
# L2 Distance from x to y:  1.459451951932642
# L2 Distance from x to y:  1.374772708486752
# L2 Distance from x to y:  0.9643650760992954
# L2 Distance from x to y:  1.319090595827292
# L2 Distance from x to y:  2.487971060924946
# L2 Distance from x to y:  2.343074902771997
# L2 Distance from x to y:  2.463736998950984
# L2 Distance from x to y:  2.0273134932713295
# L2 Distance from x to y:  1.0535653752852738
# L2 Distance from x to y:  1.5
# L2 Distance from x to y:  1.1575836902790226
# L2 Distance from x to y:  1.212435565298214
# L2 Distance from x to y:  1.794435844492636
# L2 Distance from x to y:  1.7916472867168922
# L2 Distance from x to y:  2.0639767440550294
# L2 Distance from x to y:  1.8275666882497066
# L2 Distance from x to y:  1.272792206135786
# L2 Distance from x to y:  1.9924858845171276
# L2 Distance from x to y:  2.9580398915498085
# L2 Distance from x to y:  1.8138357147217055
# L2 Distance from x to y:  1.7492855684535902
# L2 Distance from x to y:  1.7146428199482247
# L2 Distance from x to y:  1.5684387141358125
# L2 Distance from x to y:  3.0364452901377956
# L2 Distance from x to y:  1.8165902124584954
# L2 Distance from x to y:  0.6480740698407857
# L2 Distance from x to y:  0.9486832980505139
# L2 Distance from x to y:  1.1224972160321818
# L2 Distance from x to y:  0.7416198487095659
# L2 Distance from x to y:  0.6480740698407855
# L2 Distance from x to y:  1.8973665961010269
# L2 Distance from x to y:  1.9157244060668015
# L2 Distance from x to y:  1.5874507866387537
# L2 Distance from x to y:  1.2124355652982137
# L2 Distance from x to y:  1.2529964086141663
# L2 Distance from x to y:  0.5567764362830023
# L2 Distance from x to y:  0.8366600265340753
# L2 Distance from x to y:  0.7549834435270746
# L2 Distance from x to y:  1.1445523142259597
# L2 Distance from x to y:  0.7874007874011816
# L2 Distance from x to y:  0.3000000000000001
# L2 Distance from x to y:  0.7141428428542846
# L2 Distance from x to y:  2.027313493271329
# L2 Distance from x to y:  2.2671568097509267
# L2 Distance from x to y:  1.5099668870541498
# L2 Distance from x to y:  0.7874007874011811
# L2 Distance from x to y:  1.0295630140987004
# L2 Distance from x to y:  2.0952326839756963
# L2 Distance from x to y:  0.9999999999999997
# L2 Distance from x to y:  0.6244997998398396
# L2 Distance from x to y:  1.2845232578665127
# L2 Distance from x to y:  0.9848857801796107
# L2 Distance from x to y:  0.8185352771872448
# L2 Distance from x to y:  0.6928203230275507
# L2 Distance from x to y:  1.3453624047073707
# L2 Distance from x to y:  1.5652475842498526
# L2 Distance from x to y:  2.0346989949375804
# L2 Distance from x to y:  0.6708203932499368
# L2 Distance from x to y:  1.0488088481701516
# L2 Distance from x to y:  1.2247448713915887
# L2 Distance from x to y:  1.7029386365926398
# L2 Distance from x to y:  0.2449489742783171
# L2 Distance from x to y:  0.6244997998398396
# L2 Distance from x to y:  0.9000000000000002
# L2 Distance from x to y:  0.7874007874011811
# L2 Distance from x to y:  0.6244997998398395
# L2 Distance from x to y:  0.8185352771872454
# L2 Distance from x to y:  0.9486832980505139
# L2 Distance from x to y:  0.8062257748298546
# L2 Distance from x to y:  0.6244997998398398
# L2 Distance from x to y:  0.6708203932499369
# L2 Distance from x to y:  1.0677078252031311
# L2 Distance from x to y:  0.6164414002968975
# L2 Distance from x to y:  0.0
# L2 Distance from x to y:  0.7681145747868608
# L2 Distance from x to y:  4.1400483088968905
# L2 Distance from x to y:  4.153311931459037
# L2 Distance from x to y:  4.298837052040936
# L2 Distance from x to y:  4.149698784249286
# L2 Distance from x to y:  4.173727350941841
# L2 Distance from x to y:  3.818376618407356
# L2 Distance from x to y:  4.217819341792628
# L2 Distance from x to y:  4.060788100849391
# L2 Distance from x to y:  4.302324952859791
# L2 Distance from x to y:  4.106093033529562
# L2 Distance from x to y:  4.03236903073119
# L2 Distance from x to y:  4.022437072223753
# L2 Distance from x to y:  4.217819341792628
# L2 Distance from x to y:  4.631414470763764
# L2 Distance from x to y:  4.33358973600409
# L2 Distance from x to y:  4.113392760240626
# L2 Distance from x to y:  4.178516483155236
# L2 Distance from x to y:  4.102438299353203
# L2 Distance from x to y:  3.806573262134856
# L2 Distance from x to y:  4.060788100849391
# L2 Distance from x to y:  3.8118237105091834
# L2 Distance from x to y:  4.006245124802025
# L2 Distance from x to y:  4.628174586162454
# L2 Distance from x to y:  3.738983819167983
# L2 Distance from x to y:  3.7643060449437424
# L2 Distance from x to y:  3.9522145690739006
# L2 Distance from x to y:  3.896151947755631
# L2 Distance from x to y:  4.03236903073119
# L2 Distance from x to y:  4.110960958218893
# L2 Distance from x to y:  4.036087214122113
# L2 Distance from x to y:  4.00374824383352
# L2 Distance from x to y:  3.915354390090378
# L2 Distance from x to y:  4.189272013130682
# L2 Distance from x to y:  4.224926034855522
# L2 Distance from x to y:  4.106093033529562
# L2 Distance from x to y:  4.315089802078283
# L2 Distance from x to y:  4.172529209005013
# L2 Distance from x to y:  4.106093033529562
# L2 Distance from x to y:  4.387482193696061
# L2 Distance from x to y:  4.039801975344831
# L2 Distance from x to y:  4.2130748865881795
# L2 Distance from x to y:  4.374928570845472
# L2 Distance from x to y:  4.3920382511995495
# L2 Distance from x to y:  3.8405728739343035
# L2 Distance from x to y:  3.671511950137164
# L2 Distance from x to y:  4.141255848169731
# L2 Distance from x to y:  4.011234224026316
# L2 Distance from x to y:  4.240283009422838
# L2 Distance from x to y:  4.045985664828781
# L2 Distance from x to y:  4.141255848169731
# L2 Distance from x to y:  1.2529964086141663
# L2 Distance from x to y:  0.8602325267042625
# L2 Distance from x to y:  1.0677078252031311
# L2 Distance from x to y:  1.452583904633395
# L2 Distance from x to y:  0.8602325267042625
# L2 Distance from x to y:  0.8306623862918073
# L2 Distance from x to y:  0.6708203932499363
# L2 Distance from x to y:  2.2891046284519194
# L2 Distance from x to y:  0.9999999999999996
# L2 Distance from x to y:  1.4764823060233399
# L2 Distance from x to y:  2.238302928559939
# L2 Distance from x to y:  0.9486832980505133
# L2 Distance from x to y:  1.5811388300841893
# L2 Distance from x to y:  0.6082762530298215
# L2 Distance from x to y:  1.6124515496597096
# L2 Distance from x to y:  1.1401754250991376
# L2 Distance from x to y:  0.7348469228349535
# L2 Distance from x to y:  1.319090595827292
# L2 Distance from x to y:  1.0862780491200212
# L2 Distance from x to y:  1.5066519173319362
# L2 Distance from x to y:  0.3605551275463989
# L2 Distance from x to y:  1.2409673645990853
# L2 Distance from x to y:  0.734846922834953
# L2 Distance from x to y:  0.774596669241483
# L2 Distance from x to y:  1.0723805294763606
# L2 Distance from x to y:  1.0677078252031302
# L2 Distance from x to y:  1.048808848170151
# L2 Distance from x to y:  0.8124038404635958
# L2 Distance from x to y:  0.6855654600401041
# L2 Distance from x to y:  1.8439088914585773
# L2 Distance from x to y:  1.6431676725154982
# L2 Distance from x to y:  1.766352173265569
# L2 Distance from x to y:  1.3784048752090219
# L2 Distance from x to y:  0.37416573867739383
# L2 Distance from x to y:  0.8366600265340753
# L2 Distance from x to y:  0.7549834435270746
# L2 Distance from x to y:  0.9486832980505134
# L2 Distance from x to y:  1.178982612255159
# L2 Distance from x to y:  1.1575836902790229
# L2 Distance from x to y:  1.3674794331177342
# L2 Distance from x to y:  1.0816653826391964
# L2 Distance from x to y:  0.6708203932499368
# L2 Distance from x to y:  1.3190905958272918
# L2 Distance from x to y:  2.2759613353482084
# L2 Distance from x to y:  1.113552872566004
# L2 Distance from x to y:  1.0999999999999996
# L2 Distance from x to y:  1.0535653752852734
# L2 Distance from x to y:  0.9949874371066197
# L2 Distance from x to y:  2.406241883103193
# L2 Distance from x to y:  1.1532562594670797
# L2 Distance from x to y:  1.2449899597988732
# L2 Distance from x to y:  0.33166247903553997
# L2 Distance from x to y:  1.4730919862656233
# L2 Distance from x to y:  0.6480740698407857
# L2 Distance from x to y:  1.004987562112089
# L2 Distance from x to y:  2.2869193252058535
# L2 Distance from x to y:  1.2727922061357855
# L2 Distance from x to y:  1.8466185312619385
# L2 Distance from x to y:  1.174734012447073
# L2 Distance from x to y:  1.8814887722226779
# L2 Distance from x to y:  0.6633249580710797
# L2 Distance from x to y:  0.6244997998398398
# L2 Distance from x to y:  1.0295630140986998
# L2 Distance from x to y:  0.5830951894845301
# L2 Distance from x to y:  0.6403124237432849
# L2 Distance from x to y:  0.7615773105863908
# L2 Distance from x to y:  0.7211102550927978
# L2 Distance from x to y:  2.5690465157330262
# L2 Distance from x to y:  2.624880949681338
# L2 Distance from x to y:  0.8660254037844384
# L2 Distance from x to y:  1.2845232578665131
# L2 Distance from x to y:  0.4582575694955842
# L2 Distance from x to y:  2.4248711305964283
# L2 Distance from x to y:  0.5385164807134497
# L2 Distance from x to y:  1.0862780491200217
# L2 Distance from x to y:  1.5937377450509227
# L2 Distance from x to y:  0.4690415759823428
# L2 Distance from x to y:  0.282842712474618
# L2 Distance from x to y:  0.7937253933193773
# L2 Distance from x to y:  1.489966442575134
# L2 Distance from x to y:  1.816590212458495
# L2 Distance from x to y:  2.5238858928247927
# L2 Distance from x to y:  0.8366600265340757
# L2 Distance from x to y:  0.5385164807134502
# L2 Distance from x to y:  0.7810249675906653
# L2 Distance from x to y:  2.118962010041709
# L2 Distance from x to y:  0.9643650760992951
# L2 Distance from x to y:  0.6480740698407862
# L2 Distance from x to y:  0.31622776601683766
# L2 Distance from x to y:  1.0908712114635717
# L2 Distance from x to y:  1.1224972160321822
# L2 Distance from x to y:  1.1224972160321822
# L2 Distance from x to y:  0.33166247903553997
# L2 Distance from x to y:  1.3190905958272918
# L2 Distance from x to y:  1.2569805089976536
# L2 Distance from x to y:  0.9486832980505135
# L2 Distance from x to y:  0.6557438524301997
# L2 Distance from x to y:  0.6403124237432847
# L2 Distance from x to y:  0.7681145747868608
# L2 Distance from x to y:  0.0

# %%
#plot the matrix
plt.matshow(matrix)
plt.colorbar()
plt.show()

# %% [markdown]
# ## Your answer here:
# #### 3. What is the minimum number of distance computations that you can do in order to populate every value of this matrix?
# The minimum number of computation is N*N/2 because the matrix is symetric. That means we need only one half of the sqare matrix, one triangle, to know all the distance.
# #### 4. Note that the data points in your dataset are sorted by class. What do you observe in the distance matrix? [5%]
# We can visually distinguish the 3 different classes, by spoting 3 different squares. Each of them representing one of the class.

# %% [markdown]
# ## Question 3: Data Sampling [40%]
#
# Sometimes datasets are too big, or come in a streaming fashion, and it is impossible for us to process every single data point, so we have to resort to sampling methods. In this question, you will implement the popular "reservoir sampling" method, which is mostly used to obtain a uniform random sample of a data stream. Subsequently, you will experiment with sampling directly all the data and conducting stratified sampling (by class label) and observe the results in the data distribution.

# %% [markdown]
# ### Question 3a: Reservoir Sampling [20%]
# 1. Implement reservoir sampling as we saw it in class. Create a 'reservoir_sampling' function because it will be useful for the next question. [15%]
# 2. Run reservoir sampling with reservoir size $M = 15$ and plot the histogram of the petal length feature for the sampled dataset [5%]

# %%
#1-Implement reservoir sampling as we saw it in class. [15%]
import random
def reservoir_sampling(stream,M):
    res = [0]*M
    
    for i in range(M):
        res[i] = stream.loc[i]
    
    while(i < len(stream)):
        j = random.randrange(i+1)
        
        if(j < M):
            res[j] = stream.loc[i] 
            i+=1
    return pd.DataFrame(res)

# %%
#2- Run reservoir sampling with reservoir size  𝑀=15  and plot the histogram of the petal length feature for the sampled dataset
res_sample = reservoir_sampling(data, M=15)
res_histogram = res_sample['petal_length'].plot(kind="hist", grid=True, title="Petal Lengths Reservoir Sampling")

# %% [markdown]
# ### Question 3b: Stratified Sampling [20%]
# 1. Implement stratified sampling by class label, and within each stratum use the reservoir sampling function you implemented. [15%]
# 2. Run your stratified sampler with $M=5$ samples per class (so that we have 15 data points in total) and plot the histogram of the petal length feature for the sampled dataset [2.5%]
# 3. Do you observe any difference between the stratified and the non-stratified histograms? Which one resembles the original petal length distribution more closely? In order to answer this question you may want to run both sampling procedures a few times and observe which one gives a more accurate result on average. [2.5%]

# %%
#1- Implement stratified sampling by class label
def stratified_sampling(stream, M):
    #define the 3 classes
    setosas = []
    versicolors = []
    virginicas = []
    
    #Append each data point to its corresponding class
    for i in range(len(stream)):
        item = stream.loc[i]
        class_label = item["label"]
        
        if class_label == "Iris-setosa":
            setosas.append(item)
        elif class_label == "Iris-versicolor":
            versicolors.append(item)
        elif class_label == "Iris-virginica":
            virginicas.append(item)
    
    #Convert in df and reseet index 
    setosas = pd.DataFrame(setosas).reset_index(drop=True)
    versicolors = pd.DataFrame(versicolors).reset_index(drop=True)
    virginicas = pd.DataFrame(virginicas).reset_index(drop=True)
    
    # Reservoir sampling and merging
    res_setosas = reservoir_sampling(setosas, M).reset_index(drop=True)
    res_versicolors = reservoir_sampling(versicolors, M).reset_index(drop=True)
    res_virginicas = reservoir_sampling(virginicas, M).reset_index(drop=True)
    
    res_sample = pd.concat([res_setosas, res_versicolors, res_virginicas]).reset_index(drop=True)
    
    return res_sample

strat_sample = stratified_sampling(data, 5)
strat_histogram = strat_sample["petal_length"].plot(kind="hist", grid=True, title="Petal Lengths Stratified Sampling")

# %% [markdown]
# ### 3- Do you observe any difference between the stratified and the non-stratified histograms? Which one resembles the original petal length distribution more closely? In order to answer this question you may want to run both sampling procedures a few times and observe which one gives a more accurate result on average. [2.5%]
#
# The plots look similar but the stratified one is more stable, it changed less compare to the non-stratified histogram. The stratified histogram is closer to the original histogram of petal_length. It might be more accurate because we are using the 3 classes for the sampling.
